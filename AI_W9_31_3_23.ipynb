# %% [markdown]
# <a href="https://colab.research.google.com/github/Steel3264/AI/blob/main/AI_W9_31_3_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
import math 
(train_images, train_labels), (test_image, test_labels) = mnist.load_data()
x = test_image
y = test_labels
digit = train_images[1000]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()
print('so nay la', train_labels[1000])
# Out:
# so nay la 0

# %%
for i in range(36):
  plt.subplot(6,6, i+1)
  plt.tight_layout()
  plt.imshow(train_images[i], cmap='gray', interpolation='none')
  plt.title('so:{}'.format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))

model.add(Dense(10, activation='Softmax'))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 512)               401920
#
#  dense_13 (Dense)            (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images.reshape(60000, 28*28)
train_images = train_images.astype('float32')/255

test_image = test_image.reshape(10000, 28*28)
test_image = test_image.astype('float32')/255

train_images.shape

test_image.shape
# Out:
# (10000, 784)

# %%
from keras.utils import to_categorical
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

test_labels.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs = 10, batch_size=128)
test_loss, test_acc = model.evaluate(test_image, test_labels)
print('Mat mat:', test_loss)
print('Do chinh xac:', test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2638 - accuracy: 0.9248
# Epoch 2/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1074 - accuracy: 0.9683
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0716 - accuracy: 0.9789
# Epoch 4/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0513 - accuracy: 0.9843
# Epoch 5/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0387 - accuracy: 0.9885
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0296 - accuracy: 0.9912
# Epoch 7/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0224 - accuracy: 0.9934
# Epoch 8/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0168 - accuracy: 0.9955
# Epoch 9/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0137 - accuracy: 0.9960
# Epoch 10/10
# ...

# %%
img = x[999]
plt.imshow(img)
plt.show()
print(y[10])
# Out:
# 0

# %%
import numpy as np
x_pred = x[999].reshape(1, 28*28)
x_pred = x_pred.astype('float32')/255
np.argmax(model.predict(x_pred), axis=-1)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# array([9])

# %%
from keras.datasets import cifar10
import matplotlib.pyplot as plt
import math 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x = x_train
y = y_test
digit = x_train[1000]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()
# print('so nay la', y_train[1000])

# %%
for i in range(36):
  plt.subplot(6,6, i+1)
  plt.tight_layout()
  plt.imshow(x_train[i], cmap='gray', interpolation='none')
  # plt.title('so:{}'.format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))

model.add(Dense(10, activation='Softmax'))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_14 (Dense)            (None, 512)               1573376
#
#  dense_15 (Dense)            (None, 10)                5130
#
# ...
# Total params: 1,578,506
# Trainable params: 1,578,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape(50000, 3072)
x_train = x_train.astype('float32')/255

x_test = x_test.reshape(10000, 3072)
x_test = x_test.astype('float32')/255

x_train.shape

x_test.shape
# Out:
# (10000, 3072)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

y_test.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs = 10, batch_size=128)
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Mat mat:', test_loss)
print('Do chinh xac:', test_acc)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 12s 29ms/step - loss: 1.3581 - accuracy: 0.5212
# Epoch 2/10
# 391/391 [==============================] - 10s 26ms/step - loss: 1.3445 - accuracy: 0.5276
# Epoch 3/10
# 391/391 [==============================] - 11s 28ms/step - loss: 1.3324 - accuracy: 0.5300
# Epoch 4/10
# 391/391 [==============================] - 11s 28ms/step - loss: 1.3268 - accuracy: 0.5329
# Epoch 5/10
# 391/391 [==============================] - 11s 28ms/step - loss: 1.3156 - accuracy: 0.5358
# Epoch 6/10
# 391/391 [==============================] - 11s 28ms/step - loss: 1.3048 - accuracy: 0.5406
# Epoch 7/10
# 391/391 [==============================] - 11s 28ms/step - loss: 1.2985 - accuracy: 0.5421
# Epoch 8/10
# 391/391 [==============================] - 11s 28ms/step - loss: 1.2885 - accuracy: 0.5453
# Epoch 9/10
# 391/391 [==============================] - 10s 26ms/step - loss: 1.2827 - accuracy: 0.5458
# Epoch 10/10
# ...

# %%
# model.save('test1.h5')
import pandas as pd
url = 'maybay.jpg'
img = plt.imread(url)
plt.imshow(img)
plt.show()

# %%
from keras.utils import load_img, img_to_array
img = load_img(url, target_size = (32,32))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model.predict(img), axis = -1)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# array([0])
