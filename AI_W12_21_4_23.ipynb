# %% [markdown]
# <a href="https://colab.research.google.com/github/Steel3264/AI/blob/main/AI_W12_21_4_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#pip install youtube-search
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from youtube_search import YoutubeSearch
import webbrowser
from openpyxl import Workbook
data = Workbook()
sheet = data.active
mysong = input('Xin moi ban chon ten bai hat:')
print(mysong)
result = YoutubeSearch(mysong, max_results=10).to_dict()
print(result)
for i in range(10):
  print(result[i]['title'])
  print(result[i]['url_suffix'])
  url = 'https://www.youtube.com/' + result[i]['url_suffix']
  print(url)
  sheet['A' + str(i+1)]= i +1
  sheet['B' + str(i+1)]= result[i]['title']
  sheet['c' + str(i+1)]= result[i]['url_suffix']
  sheet['D' + str(i+1)]= result[i]['views']
  #webbrowser.open(url)
data.save('UTE.xlsx')
# Out:
# Xin moi ban chon ten bai hat:Shape of you
# Shape of you
# ...

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 38.1 MB/s eta 0:00:00
# ...

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename = '10ps.jpg'
img = plt.imread(filename)
plt.imshow(img)
plt.show()

# %%
filename = '5ae.jpg'
img = plt.imread(filename)
plt.imshow(img)
plt.show()

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 2/2 [==============================] - 0s 83ms/step
# {'box': [304, 31, 58, 84], 'confidence': 0.9999744892120361, 'keypoints': {'left_eye': (319, 63), 'right_eye': (347, 64), 'nose': (333, 82), 'mouth_left': (320, 94), 'mouth_right': (346, 94)}}
# {'box': [574, 37, 63, 82], 'confidence': 0.9999593496322632, 'keypoints': {'left_eye': (598, 67), 'right_eye': (626, 70), 'nose': (614, 88), 'mouth_left': (596, 96), 'mouth_right': (620, 100)}}
# {'box': [41, 35, 63, 87], 'confidence': 0.9998466968536377, 'keypoints': {'left_eye': (54, 73), 'right_eye': (83, 70), 'nose': (67, 91), 'mouth_left': (60, 104), 'mouth_right': (82, 102)}}
# {'box': [447, 48, 56, 67], 'confidence': 0.999211311340332, 'keypoints': {'left_eye': (460, 69), 'right_eye': (487, 70), 'nose': (472, 88), 'mouth_left': (460, 97), 'mouth_right': (485, 98)}}
# ...

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename = '5ae.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y, width, height = face['box']
  rect = plt.Rectangle((x,y),width,height, fill = False, color ='red')
  ax.add_patch(rect)
  #plt.savefig('/content/drive/MyDrive/AI/')
  for key, value in face['keypoints'].items():
    dot = plt.Circle(value ,radius=2, color ='red')
    ax.add_patch(dot)
    #plt.savefig('/content/drive/MyDrive/AI/')
plt.show()
# Out:
# ...
# 2/2 [==============================] - 0s 6ms/step

# %%
def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1, width, height = result_list[i]['box']
    x2, y2 = x1 + width, y1+height
    plt.subplot(1, len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
    plt.savefig('/content/drive/MyDrive/AI/')
plt.show()

filename = '5ae.jpg'
ime = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# ...
# 2/2 [==============================] - 0s 6ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = 'D.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 881ms/step
# Predicted: [('n04350905', 'suit', 0.9213831), ('n04591157', 'Windsor_tie', 0.045266766), ('n10148035', 'groom', 0.017545981)]
